# %%
import pandas as pd

# CSV 파일 로드
df = pd.read_csv('downloads/NewsResult_20250109-20250409.csv')

# %%
df
# Out:
#             뉴스 식별자        일자   언론사                       기고자  \
# 0     1.101001e+06  20250409   한겨레                    신소윤 기자
# 1     1.200201e+06  20250409  경인일보  변민철 bmc0502@kyeongin.com
# 2     1.200201e+06  20250409  경인일보      김희연 khy@kyeongin.com
# 3     1.200401e+06  20250409  인천일보                    김현우 기자
# 4     1.200201e+06  20250409  경인일보     목은수 wood@kyeongin.com
# ...            ...       ...   ...                       ...
# 3689  1.100401e+06  20250109  동아일보                       김예윤
# 3690  1.100401e+06  20250109  동아일보                       여근호
# 3691  1.100401e+06  20250109  동아일보                       NaN
# 3692  1.100201e+06  20250109  국민일보                       이도경
# 3693  1.200301e+06  20250109  기호일보                       김주희
#
#                                         제목         통합 분류1     통합 분류2  \
# 0     AI교과서 도입 한달 ‘회원 가입’조차 못한 학생 10명 중 4명       사회>교육_시험        NaN
# 1      ‘인권침해 당했던 전교조 교사’ 진실화해위, 915명 추가 규명       사회>교육_시험   사회>노동_복지
# ...
